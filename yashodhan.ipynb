# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn import metrics
from sklearn.metrics import accuracy_score

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import os
os.chdir(r"C:\Users\Sajal\Downloads\CSV")

# %%
data=pd.read_csv("C:\\Users\\Sajal\\Downloads\\CSV\\car data.csv")

# %%
data
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner
# 0        Dealer       Manual      0
# 1        Dealer       Manual      0
# ...

# %%
data.head(10)
# Out:
#         Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0           ritz  2014           3.35           5.59       27000    Petrol
# 1            sx4  2013           4.75           9.54       43000    Diesel
# 2           ciaz  2017           7.25           9.85        6900    Petrol
# 3        wagon r  2011           2.85           4.15        5200    Petrol
# 4          swift  2014           4.60           6.87       42450    Diesel
# 5  vitara brezza  2018           9.25           9.83        2071    Diesel
# 6           ciaz  2015           6.75           8.12       18796    Petrol
# 7        s cross  2015           6.50           8.61       33429    Diesel
# 8           ciaz  2016           8.75           8.89       20273    Diesel
# 9           ciaz  2015           7.45           8.92       42367    Diesel
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0
# 2      Dealer       Manual      0
# ...

# %%
data.tail(10)
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 291     brio  2015           5.40           6.10       31427    Petrol
# 292     jazz  2016           6.40           8.40       12000    Petrol
# 293     city  2010           3.25           9.90       38000    Petrol
# 294    amaze  2014           3.75           6.80       33019    Petrol
# 295     city  2015           8.55          13.09       60076    Diesel
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner
# 291      Dealer       Manual      0
# 292      Dealer       Manual      0
# 293      Dealer       Manual      0
# 294      Dealer       Manual      0
# ...

# %%
data.shape
# Out:
# (301, 9)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Car_Name       301 non-null    object
#  1   Year           301 non-null    int64
#  2   Selling_Price  301 non-null    float64
#  3   Present_Price  301 non-null    float64
#  4   Kms_Driven     301 non-null    int64
#  5   Fuel_Type      301 non-null    object
#  6   Seller_Type    301 non-null    object
#  7   Transmission   301 non-null    object
#  8   Owner          301 non-null    int64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 21.3+ KB

# %%
data.describe()
# Out:
#               Year  Selling_Price  Present_Price     Kms_Driven       Owner
# count   301.000000     301.000000     301.000000     301.000000  301.000000
# mean   2013.627907       4.661296       7.628472   36947.205980    0.043189
# std       2.891554       5.082812       8.644115   38886.883882    0.247915
# min    2003.000000       0.100000       0.320000     500.000000    0.000000
# 25%    2012.000000       0.900000       1.200000   15000.000000    0.000000
# 50%    2014.000000       3.600000       6.400000   32000.000000    0.000000
# 75%    2016.000000       6.000000       9.900000   48767.000000    0.000000
# max    2018.000000      35.000000      92.600000  500000.000000    3.000000

# %%
sns.pairplot(data)
plt.show()

# %%
sns.set_style("whitegrid")
plt.figure(figsize=(15, 10))
sns.distplot(data.Selling_Price)
plt.title('Car Price Distribution Plot')
plt.show()

# %%
data.corr()
# Out:
#                    Year  Selling_Price  Present_Price  Kms_Driven     Owner
# Year           1.000000       0.236141      -0.047584   -0.524342 -0.182104
# Selling_Price  0.236141       1.000000       0.878983    0.029187 -0.088344
# Present_Price -0.047584       0.878983       1.000000    0.203647  0.008057
# Kms_Driven    -0.524342       0.029187       0.203647    1.000000  0.089216
# Owner         -0.182104      -0.088344       0.008057    0.089216  1.000000

# %%
x=data.drop(columns=['Car_Name','Selling_Price'],axis=1)
y=data['Selling_Price']

# %%
x
# Out:
#      Year  Present_Price  Kms_Driven Fuel_Type Seller_Type Transmission  Owner
# 0    2014           5.59       27000    Petrol      Dealer       Manual      0
# 1    2013           9.54       43000    Diesel      Dealer       Manual      0
# 2    2017           9.85        6900    Petrol      Dealer       Manual      0
# 3    2011           4.15        5200    Petrol      Dealer       Manual      0
# 4    2014           6.87       42450    Diesel      Dealer       Manual      0
# ..    ...            ...         ...       ...         ...          ...    ...
# 296  2016          11.60       33988    Diesel      Dealer       Manual      0
# 297  2015           5.90       60000    Petrol      Dealer       Manual      0
# 298  2009          11.00       87934    Petrol      Dealer       Manual      0
# 299  2017          12.50        9000    Diesel      Dealer       Manual      0
# 300  2016           5.90        5464    Petrol      Dealer       Manual      0
#
# [301 rows x 7 columns]

# %%
y
# Out:
# 0       3.35
# 1       4.75
# 2       7.25
# 3       2.85
# 4       4.60
#        ...
# 296     9.50
# 297     4.00
# 298     3.35
# 299    11.50
# 300     5.30
# Name: Selling_Price, Length: 301, dtype: float64

# %%
data.replace({"Fuel_Type":{"Petrol":0,"Diesel":1,"CNG":2}},inplace=True)
data.replace({"Seller_Type":{"Individual":1,"Dealer":0}},inplace=True)
data.replace({"Transmission":{"Manual":0,"Automatic":1}},inplace=True)

# %%
data
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven  Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000          0
# 1        sx4  2013           4.75           9.54       43000          1
# 2       ciaz  2017           7.25           9.85        6900          0
# 3    wagon r  2011           2.85           4.15        5200          0
# 4      swift  2014           4.60           6.87       42450          1
# ..       ...   ...            ...            ...         ...        ...
# 296     city  2016           9.50          11.60       33988          1
# 297     brio  2015           4.00           5.90       60000          0
# 298     city  2009           3.35          11.00       87934          0
# 299     city  2017          11.50          12.50        9000          1
# 300     brio  2016           5.30           5.90        5464          0
#
#      Seller_Type  Transmission  Owner
# 0              0             0      0
# ...

# %%
x=data.drop(columns=['Car_Name','Selling_Price'],axis=1)
y=data['Selling_Price']

# %%
x
# Out:
#      Year  Present_Price  Kms_Driven  Fuel_Type  Seller_Type  Transmission  \
# 0    2014           5.59       27000          0            0             0
# 1    2013           9.54       43000          1            0             0
# 2    2017           9.85        6900          0            0             0
# 3    2011           4.15        5200          0            0             0
# 4    2014           6.87       42450          1            0             0
# ..    ...            ...         ...        ...          ...           ...
# 296  2016          11.60       33988          1            0             0
# 297  2015           5.90       60000          0            0             0
# 298  2009          11.00       87934          0            0             0
# 299  2017          12.50        9000          1            0             0
# 300  2016           5.90        5464          0            0             0
#
#      Owner
# 0        0
# 1        0
# 2        0
# 3        0
# ...

# %%
y
# Out:
# 0       3.35
# 1       4.75
# 2       7.25
# 3       2.85
# 4       4.60
#        ...
# 296     9.50
# 297     4.00
# 298     3.35
# 299    11.50
# 300     5.30
# Name: Selling_Price, Length: 301, dtype: float64

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)
print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (240, 7)
# (240,)
# (61, 7)
# (61,)

# %%
lr=LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_predicted=lr.predict(x_train)

# %%
print(y_predicted)
# Out:
# [-2.43062350e+00  1.97313550e+00 -1.62540293e+00  4.81053869e+00
#   1.82305182e+00  2.02086463e+01  1.82240444e+01  5.48531996e+00
#  -6.71214304e-01  4.59840910e+00  5.44828488e+00  5.69872459e+00
#   4.99252344e+00  2.74420426e+00  1.63527084e+00  1.91654107e+00
#   1.00884173e+01  7.96510373e-01  7.87989022e+00  4.53232619e+00
#   3.37568227e+00  4.54704954e+00  1.45039687e+01  2.29271781e+00
#   3.08198504e+00  9.26202422e-01  3.48180495e+00  1.14851619e+00
#   1.68652847e+01  1.40085330e+00  1.82947265e-01  9.16966400e+00
#   8.21516023e+00  4.31511433e+00 -2.56664991e+00  4.19262833e+00
#   6.12495501e+00  4.38850144e+00 -3.20765492e+00  7.85876515e+00
#  -7.83443958e-01  6.71120803e+00  3.85312890e+00  1.01957928e+01
#   2.46188866e+00  1.15129608e+01  2.41625540e+00 -3.09486511e-01
#   1.20681624e-01  5.67944212e+00  1.44357486e+00  6.70876867e+00
#   2.11796846e-01  1.63513067e+01  4.26353568e+00 -8.03510501e-01
# ...

# %%
score=metrics.r2_score(y_train,y_predicted)

# %%
print(score)
# Out:
# 0.8839793496750794

# %%
plt.scatter(y_train,y_predicted)
plt.xlabel("Actual Price")
plt.ylabel("Predicted Price")
plt.title("Actual vs Predicted (Train)")
plt.show()

# %%
y_pred_full_data=lr.predict(x)

# %%
print(y_pred_full_data)
# Out:
# [ 3.96379031e+00  6.57436420e+00  7.03870319e+00  2.35858968e+00
#   5.76634764e+00  8.74382695e+00  5.48531996e+00  6.94478948e+00
#   7.50352220e+00  7.03230600e+00  4.31511433e+00  7.62742375e+00
#   7.94321559e+00  5.26555804e+00  2.58269028e+00  8.21516023e+00
#   7.85876515e+00  8.21516023e+00  6.70876867e+00  3.48180495e+00
#   3.98046449e+00  5.24194397e+00  5.44828488e+00  2.92677303e+00
#   2.91768184e+00  2.64722707e+00  3.56951609e+00  4.34098321e+00
#   1.69188886e+00  7.66022681e+00  4.59840910e+00  2.41625540e+00
#   6.05797368e+00  7.10742891e+00  6.27593778e+00  6.34086217e+00
#   4.91671621e+00 -3.20765492e+00  3.97845118e+00  8.24051988e-01
#   7.34408813e+00  3.14774688e+00  2.29888190e+00  6.27167339e+00
#   1.83496695e+00  8.50347194e+00  3.08701389e+00  2.13539129e-01
#   5.26626877e+00  8.26422051e+00  1.67794118e+01  1.82240444e+01
#   1.43189936e+01  1.58087485e+01  1.21061915e+00  7.70449102e+00
# ...

# %%
score=metrics.r2_score(y,y_pred_full_data)

# %%
print(score)
# Out:
# 0.8772460832877271

# %%
plt.scatter(y,y_pred_full_data)
plt.xlabel("Actual Price")
plt.ylabel("Predicted Price")
plt.title("Actual vs Predicted")
plt.show()

# %%
print(y_pred_full_data)
# Out:
# [ 3.96379031e+00  6.57436420e+00  7.03870319e+00  2.35858968e+00
#   5.76634764e+00  8.74382695e+00  5.48531996e+00  6.94478948e+00
#   7.50352220e+00  7.03230600e+00  4.31511433e+00  7.62742375e+00
#   7.94321559e+00  5.26555804e+00  2.58269028e+00  8.21516023e+00
#   7.85876515e+00  8.21516023e+00  6.70876867e+00  3.48180495e+00
#   3.98046449e+00  5.24194397e+00  5.44828488e+00  2.92677303e+00
#   2.91768184e+00  2.64722707e+00  3.56951609e+00  4.34098321e+00
#   1.69188886e+00  7.66022681e+00  4.59840910e+00  2.41625540e+00
#   6.05797368e+00  7.10742891e+00  6.27593778e+00  6.34086217e+00
#   4.91671621e+00 -3.20765492e+00  3.97845118e+00  8.24051988e-01
#   7.34408813e+00  3.14774688e+00  2.29888190e+00  6.27167339e+00
#   1.83496695e+00  8.50347194e+00  3.08701389e+00  2.13539129e-01
#   5.26626877e+00  8.26422051e+00  1.67794118e+01  1.82240444e+01
#   1.43189936e+01  1.58087485e+01  1.21061915e+00  7.70449102e+00
# ...

# %%
print(y)
# Out:
# 0       3.35
# 1       4.75
# 2       7.25
# 3       2.85
# 4       4.60
#        ...
# 296     9.50
# 297     4.00
# 298     3.35
# 299    11.50
# 300     5.30
# Name: Selling_Price, Length: 301, dtype: float64

# %%
from sklearn.ensemble import RandomForestRegressor
rf=RandomForestRegressor(n_estimators=100)
rf.fit(x_train,y_train)
# Out:
# RandomForestRegressor()

# %%
y_rf_test=rf.predict(x_train)
score_new=metrics.r2_score(y_train,y_rf_test)

# %%
print(score_new)
# Out:
# 0.9804550329391899

# %%
plt.scatter(y_train,y_rf_test)
plt.xlabel("Actual Price")
plt.ylabel("Predicted Price")
plt.title("Actual vs Predicted (Train)")
plt.show()

# %%
full_dataset=rf.predict(x)
s_rf=metrics.r2_score(y,full_dataset)
print(s_rf)
# Out:
# 0.978111841399701

# %%
plt.scatter(y,full_dataset)
plt.xlabel("Actual Price")
plt.ylabel("Predicted Price")
plt.title("Actual vs Predicted")
plt.show()

# %%
name=['Random Forest Regressor','Linear Regression']
s=[s_rf,score]
plt.figure(figsize=(8, 8))
plt.bar(name,s,color=['red','green'],width=0.2)
plt.xlabel('Algorithm Names')
plt.ylabel('Accuracy Scores')
plt.title("Accuracy Comparasion")
plt.show()
print("Random Forest Score:",s_rf)
print("Linear Regression Score:",score)
# Out:
# Random Forest Score: 0.9828381924062078
# Linear Regression Score: 0.8772460832877271
